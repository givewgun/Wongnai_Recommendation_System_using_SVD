# %%
# from pyspark import SparkContext
# sc = SparkContext()

# %%
# sc

# %%
import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine
from scipy import sparse

# %%
#must haveeee
engine = create_engine('mysql+pymysql://root:123456789@localhost:3306/wongnai')

# %%
df_train = pd.read_csv("train.csv")
df_train.head()
del df_train['timestamp']
df_train.head()
# Out:
#    user_id  restaurant_id      type
# 0        2          17782  check-in
# 1     6219          22458  check-in
# 2        3          54559  check-in
# 3        4           3377  check-in
# 4        4          27473  check-in

# %%
len(df_train[df_train['type']=='bookmark'])
# Out:
# 516845

# %%
df_test = pd.read_csv("test.csv",header=None,names=['user_id','rec_amount'])
df_test.head()
# Out:
#    user_id  rec_amount
# 0        2          20
# 1        3          30
# 2        4         373
# 3        5          30
# 4        9         190

# %%
not_in_train=set(df_test.user_id)-set(df_train.user_id)
len(not_in_train)
# Out:
# 145843

# %%
sql_checkin_activity_df = pd.read_sql_query('SELECT doer_id,restaurant_id FROM w_activity WHERE activity_type=9', engine)
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)

# %%
unique_checkin_activity_df=sql_checkin_activity_df.drop_duplicates()
unique_checkin_activity_df
# Out:
#          doer_id  restaurant_id
# 0              2          17782
# 1           6219          22458
# 4              4           8188
# 6              3          54559
# 7              4           3377
# 8              4          27473
# 10             4           4263
# 11             3           9184
# 12             4            369
# 13             3           2949
# 14             4          14755
# 15             3          11444
# 16            14           2977
# 17             4           7686
# 18         92939          23748
# 19             4          14768
# 20             4          24785
# 21             3          13135
# 22         92939          26098
# 23             3          12197
# 24             3         117803
# 25             3           9818
# 26             4          67336
# 27            14          10447
# 28            14          17782
# 29             4           9574
# 31            14          28028
# 32             4           7165
# ...

# %%
len((set(df_test.user_id)-set(df_train.user_id))-set(unique_checkin_activity_df.doer_id))
# Out:
# 112628

# %%
sql_bookmark_activity_df = pd.read_sql_query('SELECT id,owner_id,bookmarkable_id FROM w_bookmark_item', engine)
sql_bookmark_activity_df
# Out:
#               id  owner_id  bookmarkable_id
# 0              1         1                7
# 1              2         1             3622
# 2              3         1             5649
# 3              4         1             1873
# 4              5         1             3552
# 5              6         1             3714
# 6              7         1             9595
# 7              8         1            10866
# 8              9         1            11596
# 9             10         1            12894
# 10            11         1            14531
# 11            12         1            28653
# 12            13         1           122561
# 13            14         1           122742
# 14            15         1           127768
# 15            18         2             5720
# 16            20         2            14606
# 17            22         2           122938
# 18            27         3             2949
# 19            30         3            27131
# ...

# %%
unique_bookmark_activity_df=sql_bookmark_activity_df.drop_duplicates()
unique_bookmark_activity_df
# Out:
#               id  owner_id  bookmarkable_id
# 0              1         1                7
# 1              2         1             3622
# 2              3         1             5649
# 3              4         1             1873
# 4              5         1             3552
# 5              6         1             3714
# 6              7         1             9595
# 7              8         1            10866
# 8              9         1            11596
# 9             10         1            12894
# 10            11         1            14531
# 11            12         1            28653
# 12            13         1           122561
# 13            14         1           122742
# 14            15         1           127768
# 15            18         2             5720
# 16            20         2            14606
# 17            22         2           122938
# 18            27         3             2949
# 19            30         3            27131
# ...

# %%
sql_bookmark_type_df = pd.read_sql_query('SELECT item_id,label_id FROM w_bookmark_item_label', engine)
sql_bookmark_type_df.head()
# Out:
#    item_id  label_id
# 0        1         1
# 1        2         1
# 2        3         1
# 3        4         1
# 4        5         1

# %%
sql_bookmark_type_df.rename(columns={'item_id':'id'}, inplace=True)

# %%
unique_bookmark_activity_df=pd.merge(unique_bookmark_activity_df, sql_bookmark_type_df, how='left', on=['id'])
unique_bookmark_activity_df.head()
# Out:
#    id  owner_id  bookmarkable_id  label_id
# 0   1         1                7       1.0
# 1   2         1             3622       1.0
# 2   3         1             5649       1.0
# 3   4         1             1873       1.0
# 4   5         1             3552       1.0

# %%
unique_bookmark_activity_df[unique_bookmark_activity_df.label_id.isnull()]
# Out:
#               id  owner_id  bookmarkable_id  label_id
# 124          114         4           127530       NaN
# 155          135         4             8601       NaN
# 436          474        54             3366       NaN
# 455          493        81            16264       NaN
# 525          554       157             5914       NaN
# 549          569       157             9395       NaN
# 735          813       275            10629       NaN
# 1013        1115       905             8898       NaN
# 1022        1124       905            14473       NaN
# 1042        1145       921             3475       NaN
# 1258        1410      1238             8601       NaN
# 1920        2113      2240             8601       NaN
# 2129        2362      2359             8601       NaN
# 2472        2803      2739             7255       NaN
# 2490        2818      2739             8601       NaN
# 2572        2892      2739            61117       NaN
# ...

# %%
unique_bookmark_activity_df.loc[unique_bookmark_activity_df.label_id.isnull(), 'label_id'] = 2

# %%
unique_bookmark_activity_df[~unique_bookmark_activity_df.label_id.isin([1,2])]
# Out:
#               id  owner_id  bookmarkable_id  label_id
# 22            31         4             2496   35704.0
# 25            32         4             7668   35704.0
# 291          236         9            10105    2462.0
# 305          257         9            25226    2462.0
# 319          277         9           130474   24463.0
# 335          309        10           136297    3484.0
# 355          353        14            15875   10748.0
# 605          625       247             8446   38349.0
# 610          629       247             9418    7620.0
# 790          868       351            24998   39641.0
# 810          887       414                4   78515.0
# 812          894       414             2431   73936.0
# 813          894       414             2431   78513.0
# 815          895       414             2496   78518.0
# 818          898       414             2957   73937.0
# 820          900       414             3011   73935.0
# ...

# %%
unique_bookmark_activity_df.loc[~unique_bookmark_activity_df.label_id.isin([1,2]), 'label_id'] = 2

# %%
len(((set(df_test.user_id)-set(df_train.user_id))-set(unique_checkin_activity_df.doer_id))-set(sql_bookmark_activity_df.owner_id))
# Out:
# 85420

# %%
unique_checkin_activity_df.rename(columns={"doer_id": "user_id"},inplace=True)
unique_checkin_activity_df['type']='check-in'
unique_checkin_activity_df.head()
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    user_id  restaurant_id      type
# 0        2          17782  check-in
# 1     6219          22458  check-in
# 4        4           8188  check-in
# 6        3          54559  check-in
# 7        4           3377  check-in

# %%
unique_bookmark_activity_df.rename(columns={"owner_id": "user_id",'bookmarkable_id':'restaurant_id'},inplace=True)
unique_bookmark_activity_df.drop(columns=['id'],inplace=True)
unique_bookmark_activity_df['label_id'] = np.where(unique_bookmark_activity_df.label_id==1, 'Fbookmark', 'bookmark')
# unique_bookmark_activity_df['type']='bookmark'

# %%
unique_bookmark_activity_df.rename(columns={"label_id": "type"},inplace=True)
unique_bookmark_activity_df
# Out:
#          user_id  restaurant_id       type
# 0              1              7  Fbookmark
# 1              1           3622  Fbookmark
# 2              1           5649  Fbookmark
# 3              1           1873  Fbookmark
# 4              1           3552  Fbookmark
# 5              1           3714  Fbookmark
# 6              1           9595  Fbookmark
# 7              1          10866  Fbookmark
# 8              1          11596  Fbookmark
# 9              1          12894  Fbookmark
# 10             1          14531  Fbookmark
# 11             1          28653  Fbookmark
# 12             1         122561  Fbookmark
# 13             1         122742  Fbookmark
# 14             1         127768  Fbookmark
# 15             2           5720  Fbookmark
# 16             2          14606   bookmark
# 17             2         122938   bookmark
# 18             3           2949  Fbookmark
# 19             3          27131  Fbookmark
# 20             4           2496  Fbookmark
# ...

# %%
unique_bookmark_activity_df.head()
# Out:
#    user_id  restaurant_id       type
# 0        1              7  Fbookmark
# 1        1           3622  Fbookmark
# 2        1           5649  Fbookmark
# 3        1           1873  Fbookmark
# 4        1           3552  Fbookmark

# %%
unique_checkin_activity_df.append(unique_bookmark_activity_df)
df=df_train.append(unique_checkin_activity_df.append(unique_bookmark_activity_df,ignore_index=True),ignore_index=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    user_id  restaurant_id      type
# 0        2          17782  check-in
# 1     6219          22458  check-in
# 2        3          54559  check-in
# 3        4           3377  check-in
# 4        4          27473  check-in

# %%
temp = df.groupby(['restaurant_id'], as_index = True).count()
temp = temp[temp['user_id'] > 20]
temp.sort_values(by='restaurant_id',  ascending=True)
del temp['type']

# %%
temp.sort_values(by='user_id',  ascending=False)
# Out:
#                user_id
# restaurant_id
# 12340             5277
# 2858              4793
# 10183             4546
# 4                 4474
# 2785              4467
# 203990            4333
# 14                4273
# 7699              4045
# 7021              4015
# 9053              3900
# 131724            3878
# 8201              3855
# 8795              3760
# 117954            3561
# 10105             3552
# 2559              3540
# 3475              3497
# 2454              3410
# 1262              3350
# 5290              3196
# 2856              3176
# 1486              3107
# 5720              3021
# 8344              3009
# 197992            2993
# 8742              2980
# 2851              2945
# 4285              2929
# 9023              2926
# 8476              2884
# ...                ...
# 197026              21
# 170619              21
# 170312              21
# 270711              21
# 2233                21
# 152137              21
# 169627              21
# ...

# %%
res_id_arr = temp.index.tolist()
res_id_arr
# Out:
# [2,
#  4,
#  5,
#  6,
#  7,
#  9,
#  10,
#  14,
#  15,
#  16,
#  18,
#  19,
#  20,
#  21,
#  22,
#  23,
#  24,
#  26,
#  27,
#  28,
#  29,
#  30,
#  31,
#  33,
#  34,
#  35,
#  37,
#  38,
#  39,
#  40,
#  41,
#  42,
#  49,
#  50,
#  51,
#  52,
#  54,
#  60,
#  63,
#  67,
#  72,
#  76,
#  78,
#  79,
#  80,
#  88,
#  89,
#  97,
#  98,
#  99,
#  102,
#  103,
#  104,
#  106,
#  109,
#  114,
#  116,
#  117,
#  122,
#  125,
#  126,
#  144,
#  146,
#  147,
#  150,
#  154,
#  156,
#  161,
#  162,
#  166,
#  169,
#  170,
#  171,
#  175,
#  178,
#  179,
#  180,
#  186,
#  187,
#  190,
#  193,
#  195,
#  197,
#  198,
#  200,
#  203,
#  204,
#  205,
#  208,
#  210,
#  213,
#  214,
#  217,
#  218,
#  221,
#  223,
#  224,
#  225,
#  228,
#  230,
#  231,
#  237,
#  242,
#  244,
#  245,
#  246,
#  247,
#  248,
#  251,
#  254,
#  257,
#  261,
#  266,
#  267,
#  270,
#  271,
#  274,
#  276,
#  280,
#  284,
#  289,
#  295,
#  305,
#  313,
#  314,
#  321,
#  328,
#  335,
#  342,
#  344,
#  350,
#  351,
# ...

# %%
res_dict  = {k: v for v, k in enumerate(res_id_arr)}
res_dict
# Out:
# {2: 0,
#  4: 1,
#  5: 2,
#  6: 3,
#  7: 4,
#  9: 5,
#  10: 6,
#  14: 7,
#  15: 8,
#  16: 9,
#  18: 10,
#  19: 11,
#  20: 12,
#  21: 13,
#  22: 14,
#  23: 15,
#  24: 16,
#  26: 17,
#  27: 18,
#  28: 19,
#  29: 20,
#  30: 21,
#  31: 22,
#  33: 23,
#  34: 24,
#  35: 25,
#  37: 26,
#  38: 27,
#  39: 28,
#  40: 29,
#  41: 30,
#  42: 31,
#  49: 32,
#  50: 33,
#  51: 34,
#  52: 35,
#  54: 36,
#  60: 37,
#  63: 38,
#  67: 39,
#  72: 40,
#  76: 41,
#  78: 42,
#  79: 43,
#  80: 44,
#  88: 45,
#  89: 46,
#  97: 47,
#  98: 48,
#  99: 49,
#  102: 50,
#  103: 51,
#  104: 52,
#  106: 53,
#  109: 54,
#  114: 55,
#  116: 56,
#  117: 57,
#  122: 58,
#  125: 59,
#  126: 60,
#  144: 61,
#  146: 62,
#  147: 63,
#  150: 64,
#  154: 65,
#  156: 66,
#  161: 67,
#  162: 68,
#  166: 69,
#  169: 70,
#  170: 71,
#  171: 72,
#  175: 73,
#  178: 74,
#  179: 75,
#  180: 76,
#  186: 77,
#  187: 78,
#  190: 79,
#  193: 80,
#  195: 81,
#  197: 82,
#  198: 83,
#  200: 84,
#  203: 85,
#  204: 86,
#  205: 87,
# ...

# %%
df = df[df.restaurant_id.isin(res_id_arr)]
df.head()
# Out:
#    user_id  restaurant_id      type
# 1     6219          22458  check-in
# 3        4           3377  check-in
# 4        4          27473  check-in
# 6        3           9184  check-in
# 7        4            369  check-in

# %%
df['ntype'] = df.type.replace({'check-in':1, 'bookmark':1.5, 'Fbookmark':2})
df.head()
# Out:
#    user_id  restaurant_id      type  ntype
# 1     6219          22458  check-in    1.0
# 3        4           3377  check-in    1.0
# 4        4          27473  check-in    1.0
# 6        3           9184  check-in    1.0
# 7        4            369  check-in    1.0

# %%
df2 = df.groupby(['user_id','restaurant_id'], as_index = False).sum()
df2.rename(columns={'ntype': 'factor'},inplace=True)
df2.head(10)
# Out:
#    user_id  restaurant_id  factor
# 0        1              7     3.5
# 1        1           1873     3.5
# 2        1           3552     3.5
# 3        1           3622     3.5
# 4        1           3714     3.5
# 5        1           5649     3.5
# 6        1           9595     3.5
# 7        1          10866     3.5
# 8        1          11596     3.5
# 9        1          12894     3.5

# %%
avg_factor=df2.factor.mean()
user_res_rating_df=pd.read_csv('user_res_rating_df.csv')
user_res_rating_df=user_res_rating_df[user_res_rating_df.restaurant_id.isin(list(df2.restaurant_id.values))]
df3=pd.merge(df2,user_res_rating_df,how='outer',on=['user_id','restaurant_id'])

# %%
df3.head()
# Out:
#    user_id  restaurant_id  factor    rating
# 0        1              7     3.5       NaN
# 1        1           1873     3.5       NaN
# 2        1           3552     3.5  0.532399
# 3        1           3622     3.5       NaN
# 4        1           3714     3.5       NaN

# %%
avg_rating=df3.rating.mean()
avg_rating
# Out:
# 0.5361487125642208

# %%
df3['rating']=np.where(df3.rating.isnull(),avg_rating,df3.rating)
df3['factor']=np.where(df3.factor.isnull(),avg_factor,df3.factor)

# %%
df3['nfactor']=df3['factor']*df3['rating']
df3
# Out:
#          user_id  restaurant_id    factor    rating   nfactor
# 0              1              7  3.500000  0.536149  1.876520
# 1              1           1873  3.500000  0.536149  1.876520
# 2              1           3552  3.500000  0.532399  1.863398
# 3              1           3622  3.500000  0.536149  1.876520
# 4              1           3714  3.500000  0.536149  1.876520
# 5              1           5649  3.500000  0.536149  1.876520
# 6              1           9595  3.500000  0.536149  1.876520
# 7              1          10866  3.500000  0.536149  1.876520
# 8              1          11596  3.500000  0.532399  1.863398
# 9              1          12894  3.500000  0.536149  1.876520
# 10             1          14531  3.500000  0.536149  1.876520
# 11             1          28653  3.500000  0.532399  1.863398
# 12             1         122561  3.500000  0.532399  1.863398
# 13             2              4  4.500000  0.592154  2.664692
# ...

# %%
df3=df3[['user_id','restaurant_id','nfactor']]
df3.head()
# Out:
#    user_id  restaurant_id   nfactor
# 0        1              7  1.876520
# 1        1           1873  1.876520
# 2        1           3552  1.863398
# 3        1           3622  1.876520
# 4        1           3714  1.876520

# %%
df2=df3.rename(columns={'nfactor':'factor'})
del df3
df2.head()
# Out:
#    user_id  restaurant_id    factor
# 0        1              7  1.876520
# 1        1           1873  1.876520
# 2        1           3552  1.863398
# 3        1           3622  1.876520
# 4        1           3714  1.876520

# %%
res_rank_score_dict=np.load('res_rank_score_dict.npy').item()

# %%
res_rank_score_dict
# Out:
# {2: 1.0521963296009542,
#  4: 1.7096929584373846,
#  5: 1.0368959180966986,
#  6: 1.0,
#  7: 1.2813419134367328,
#  9: 1.0,
#  10: 1.0,
#  14: 1.3075985406208406,
#  15: 1.0584479468051864,
#  16: 1.0,
#  18: 1.0,
#  19: 1.0,
#  20: 1.066255358537096,
#  21: 1.1500782085286385,
#  22: 1.0,
#  23: 1.0,
#  24: 1.0112703236593958,
#  26: 1.000031328482994,
#  27: 1.0295372849910285,
#  28: 1.0166722607241534,
#  29: 1.051790818626714,
#  30: 1.0076845394851746,
#  31: 1.0,
#  33: 1.0,
#  34: 1.0795410127942782,
#  35: 1.004805619829303,
#  37: 1.005898608900148,
#  38: 1.0574152256497926,
#  39: 1.0,
#  40: 1.0,
#  41: 1.0794204277082484,
#  42: 1.0587339416494193,
#  49: 1.0869220068503265,
#  50: 1.045188974717735,
#  51: 1.0281309727861732,
#  52: 1.000004930569614,
#  54: 1.0054813828739801,
#  60: 1.01704137979657,
#  63: 1.1188369857412848,
#  67: 1.0188901458322206,
#  72: 1.0323924212684927,
#  76: 1.0,
#  78: 1.0074474102089905,
#  79: 1.025968100957862,
#  80: 1.0,
# ...

# %%
res_rank_score_df=pd.DataFrame([[k,v] for k,v in res_rank_score_dict.items()],columns=['restaurant_id','rscore'])

# %%
df3=pd.merge(df2,res_rank_score_df,how='left',on=['restaurant_id'])
df3.head()
# Out:
#    user_id  restaurant_id    factor    rscore
# 0        1              7  1.876520  1.281342
# 1        1           1873  1.876520  1.000000
# 2        1           3552  1.863398  1.000000
# 3        1           3622  1.876520  1.062468
# 4        1           3714  1.876520  1.006499

# %%
df3['factor']=df3['factor']*df3['rscore']

# %%
df2=df3[['user_id','restaurant_id','factor']]

# %%
df2.head()
# Out:
#    user_id  restaurant_id    factor
# 0        1              7  2.404464
# 1        1           1873  1.876520
# 2        1           3552  1.863398
# 3        1           3622  1.993743
# 4        1           3714  1.888716

# %%
Mean=(df2.groupby(['user_id'],as_index=False,sort=False).mean()).rename(columns={'factor':'factor_mean'})
df3=pd.merge(df2,Mean[['user_id','factor_mean']],on='user_id',how='left',sort=False)
df3['factor_adjusted']=df3['factor']-df3['factor_mean']
# df3 = df3[['user_id', 'restaurant_id', 'factor_adjusted']]
# df3.rename(columns={"factor_adjusted": "factor"},inplace=True)

# %%
df3
# Out:
#          user_id  restaurant_id    factor  factor_mean  factor_adjusted
# 0              1              7  2.404464     1.015873         1.388591
# 1              1           1873  1.876520     1.015873         0.860648
# 2              1           3552  1.863398     1.015873         0.847525
# 3              1           3622  1.993743     1.015873         0.977870
# 4              1           3714  1.888716     1.015873         0.872843
# 5              1           5649  1.876520     1.015873         0.860648
# 6              1           9595  1.922398     1.015873         0.906525
# 7              1          10866  1.876520     1.015873         0.860648
# 8              1          11596  2.555528     1.015873         1.539655
# 9              1          12894  1.876808     1.015873         0.860935
# 10             1          14531  1.942543     1.015873         0.926670
# 11             1          28653  1.863398     1.015873         0.847525
# ...

# %%
temp = df3.groupby(['user_id']).count()
user_id_arr = temp.index.tolist()
user_dict  = {k: v for v, k in enumerate(user_id_arr)}
user_dict
# Out:
# {1: 0,
#  2: 1,
#  3: 2,
#  4: 3,
#  5: 4,
#  6: 5,
#  7: 6,
#  8: 7,
#  9: 8,
#  10: 9,
#  11: 10,
#  12: 11,
#  13: 12,
#  14: 13,
#  15: 14,
#  16: 15,
#  17: 16,
#  18: 17,
#  19: 18,
#  20: 19,
#  22: 20,
#  23: 21,
#  26: 22,
#  27: 23,
#  28: 24,
#  29: 25,
#  30: 26,
#  33: 27,
#  34: 28,
#  35: 29,
#  37: 30,
#  38: 31,
#  39: 32,
#  45: 33,
#  46: 34,
#  48: 35,
#  49: 36,
#  50: 37,
#  52: 38,
#  54: 39,
#  55: 40,
#  58: 41,
#  59: 42,
#  60: 43,
#  61: 44,
#  62: 45,
#  63: 46,
#  65: 47,
#  71: 48,
#  73: 49,
#  75: 50,
#  77: 51,
#  78: 52,
#  80: 53,
#  81: 54,
#  83: 55,
#  86: 56,
#  88: 57,
#  90: 58,
#  91: 59,
#  93: 60,
#  95: 61,
#  98: 62,
#  101: 63,
#  102: 64,
#  103: 65,
#  104: 66,
#  105: 67,
#  106: 68,
#  109: 69,
#  110: 70,
#  111: 71,
#  114: 72,
#  115: 73,
#  118: 74,
#  122: 75,
#  123: 76,
#  124: 77,
#  127: 78,
#  129: 79,
#  132: 80,
#  134: 81,
#  136: 82,
#  142: 83,
#  144: 84,
#  145: 85,
#  146: 86,
#  149: 87,
#  150: 88,
#  151: 89,
# ...

# %%
n_users = user_dict[df3['user_id'].max()]
n_items = res_dict[df3['restaurant_id'].max()]

print('Num. of Users: '+ str(n_users))
print('Num of Restaurant: '+str(n_items))
# Out:
# Num. of Users: 444354
# Num of Restaurant: 28229

# %%
# np.save('res_dict.npy', res_dict) 
# np.save('user_dict.npy',user_dict)

# %%
train_data_matrix=sparse.lil_matrix((n_users+1, n_items+1), dtype=np.float64)
# train_data_matrix = np.zeros((n_users+1, n_items+1), dtype = 'float16')
# # print("Matrix->i = ")
# # print("Matrix->j = ") 
# # print("value = ")

for line in df3.itertuples():
    train_data_matrix[user_dict[line[1]], res_dict[line[2]]] = line[5]
#     i = user_dict[line[1]]
#     j = res_dict[line[2]]
#     v = line[3]
#     print(i , j , v)

# print(train_data_matrix)

# %%
for line in df3.itertuples():
    print(line)
    print (line[5])
    break
# Out:
# Pandas(Index=0, user_id=1, restaurant_id=7, factor=2.4044643603528786, factor_mean=1.0158729562698168, factor_adjusted=1.3885914040830618)
# 1.3885914040830618

# %%
factor_mean_data_matrix=sparse.lil_matrix((n_users+1, n_items+1), dtype=np.float64)
# factor_mean_data_matrix = np.zeros((n_users+1, n_items+1), dtype = 'float16')
# # print("Matrix->i = ")
# # print("Matrix->j = ") 
# # print("value = ")

for line in df3.itertuples():
    factor_mean_data_matrix[user_dict[line[1]], res_dict[line[2]]] = line[4]
#     i = user_dict[line[1]]
#     j = res_dict[line[2]]
#     v = line[3]
#     print(i , j , v)

#print(factor_mean_data_matrix)

# %%
# train_data_matrix[1][res_dict[21]]

# %%
# train_data_matrix[1][1]

# %%
# import csv
# with open("factor_mean_data_matrix.csv","w+") as my_csv:
#     csvWriter = csv.writer(my_csv,delimiter=',')
#     csvWriter.writerows(factor_mean_data_matrix)

# %%
#res_dict[1873]

# %%
from scipy import sparse

# %%
sparse.save_npz("train_data_matrix.npz", sparse.csr_matrix(train_data_matrix))

# %%
sparse.save_npz("factor_mean_data_matrix.npz", sparse.csr_matrix(factor_mean_data_matrix))

# %%
# import csv
# with open("top_res.csv","w+") as my_csv:
#     csvWriter = csv.writer(my_csv,delimiter=',')
#     csvWriter.writerows([top_res])import csv
# with open("top_res.csv","w+") as my_csv:
#     csvWriter = csv.writer(my_csv,delimiter=',')
#     csvWriter.writerows([top_res])

# %%
np.save('res_dict.npy', res_dict) 
np.save('user_dict.npy',user_dict)

# %%
############## my idea ###############

# %%
len(res_dict)
# Out:
# 28230
